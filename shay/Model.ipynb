# %%
#Libraries 
import pandas as pd 
import numpy as np 

# data visualization packages 
import matplotlib.pyplot as plt 
import seaborn as sns 
# %matplotlib inline
pd.set_option('max_columns', None)

# SMOTE package to address imbalanced classes 
from imblearn.over_sampling import SMOTE 

# machine learning packages (sklearn + xgboost)
from sklearn.model_selection import train_test_split, GridSearchCV, RandomizedSearchCV, cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc
from sklearn.ensemble import RandomForestClassifier, BaggingClassifier, VotingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
import xgboost as xgb

from warnings import filterwarnings
filterwarnings('ignore')

# %%
df = pd.read_csv('../data/cleaned_df.csv')
df
# Out:
#        Unnamed: 0             race  gender      age  admission_type_id  \
# 0               0        Caucasian  Female   [0-10)                  6
# 1               1        Caucasian  Female  [10-20)                  1
# 2               2  AfricanAmerican  Female  [20-30)                  1
# 3               3        Caucasian    Male  [30-40)                  1
# 4               4        Caucasian    Male  [40-50)                  1
# ...           ...              ...     ...      ...                ...
# 71513      101754        Caucasian  Female  [70-80)                  1
# 71514      101755            Other  Female  [40-50)                  1
# 71515      101756            Other  Female  [60-70)                  1
# 71516      101758        Caucasian  Female  [80-90)                  1
# 71517      101765        Caucasian    Male  [70-80)                  1
#
#        discharge_disposition_id  admission_source_id  time_in_hospital  \
# 0                            25                    1                 1
# 1                             1                    7                 3
# 2                             1                    7                 2
# 3                             1                    7                 2
# 4                             1                    7                 1
# ...                         ...                  ...               ...
# 71513                         1                    7                 9
# 71514                         1                    7                14
# 71515                         1                    7                 2
# 71516                         1                    7                 5
# 71517                         1                    7                 6
#
#        num_lab_procedures  num_procedures  num_medications  number_outpatient  \
# 0                      41               0                1                  0
# 1                      59               0               18                  0
# 2                      11               5               13                  2
# 3                      44               1               16                  0
# 4                      51               0                8                  0
# ...                   ...             ...              ...                ...
# 71513                  50               2               33                  0
# 71514                  73               6               26                  0
# 71515                  46               6               17                  1
# 71516                  76               1               22                  0
# 71517                  13               3                3                  0
#
#        number_emergency  number_inpatient  \
# 0                     0                 0
# 1                     0                 0
# 2                     0                 1
# 3                     0                 0
# 4                     0                 0
# ...                 ...               ...
# 71513                 0                 0
# 71514                 1                 0
# 71515                 1                 1
# 71516                 1                 0
# 71517                 0                 0
#
#                                                  diag_1  \
# 0                                              Diabetes
# 1                 Endocrine/Metabolic/Immunity Disorder
# 2      Complications of Pregnancy/Childbirth/Puerperium
# 3                      Infectious and Parasitic Disease
# 4                                             Neoplasms
# ...                                                 ...
# 71513                                 Digestive Disease
# 71514                             Genitourinary Disease
# 71515                              Injury and Poisoning
# 71516                                   Mental Disorder
# 71517                                 Digestive Disease
#
#                                  diag_2  \
# 0                               Missing
# 1                              Diabetes
# 2                              Diabetes
# 3                              Diabetes
# 4                             Neoplasms
# ...                                 ...
# 71513                 Digestive Disease
# 71514             Genitourinary Disease
# 71515             Genitourinary Disease
# 71516  Infectious and Parasitic Disease
# 71517                 Digestive Disease
#
#                                       diag_3  number_diagnoses max_glu_serum  \
# 0                                    Missing                 1          None
# 1      Endocrine/Metabolic/Immunity Disorder                 9          None
# 2               External Injury/Supplemental                 6          None
# 3                        Circulatory Disease                 7          None
# 4                                   Diabetes                 5          None
# ...                                      ...               ...           ...
# 71513                               Diabetes                 9          None
# 71514                    Respiratory Disease                 9          None
# 71515                    Circulatory Disease                 9          None
# 71516                        Mental Disorder                 9          None
# 71517  Symptoms/Signs/Ill-Defined Conditions                 9          None
#
#       A1Cresult metformin repaglinide nateglinide chlorpropamide glimepiride  \
# 0          None        No          No          No             No          No
# 1          None        No          No          No             No          No
# 2          None        No          No          No             No          No
# 3          None        No          No          No             No          No
# 4          None        No          No          No             No          No
# ...         ...       ...         ...         ...            ...         ...
# 71513        >7        No          No          No             No          No
# 71514        >8        No          No          No             No          No
# 71515      None        No          No          No             No          No
# 71516      None        No          No          No             No          No
# 71517      None        No          No          No             No          No
#
#       acetohexamide glipizide glyburide tolbutamide pioglitazone  \
# 0                No        No        No          No           No
# 1                No        No        No          No           No
# 2                No    Steady        No          No           No
# 3                No        No        No          No           No
# 4                No    Steady        No          No           No
# ...             ...       ...       ...         ...          ...
# 71513            No        No        Up          No           No
# 71514            No    Steady        No          No           No
# 71515            No        No        No          No           No
# 71516            No        No        No          No           No
# 71517            No        No        No          No           No
#
#       rosiglitazone acarbose miglitol troglitazone tolazamide examide  \
# 0                No       No       No           No         No      No
# 1                No       No       No           No         No      No
# 2                No       No       No           No         No      No
# 3                No       No       No           No         No      No
# 4                No       No       No           No         No      No
# ...             ...      ...      ...          ...        ...     ...
# 71513            No       No       No           No         No      No
# 71514            No       No       No           No         No      No
# 71515            No       No       No           No         No      No
# 71516            No       No       No           No         No      No
# 71517            No       No       No           No         No      No
#
#       citoglipton insulin glyburide-metformin glipizide-metformin  \
# 0              No      No                  No                  No
# 1              No      Up                  No                  No
# 2              No      No                  No                  No
# 3              No      Up                  No                  No
# 4              No  Steady                  No                  No
# ...           ...     ...                 ...                 ...
# 71513          No  Steady                  No                  No
# 71514          No      Up                  No                  No
# 71515          No  Steady                  No                  No
# 71516          No      Up                  No                  No
# 71517          No      No                  No                  No
#
#       glimepiride-pioglitazone metformin-rosiglitazone metformin-pioglitazone  \
# 0                           No                      No                     No
# 1                           No                      No                     No
# 2                           No                      No                     No
# 3                           No                      No                     No
# 4                           No                      No                     No
# ...                        ...                     ...                    ...
# 71513                       No                      No                     No
# 71514                       No                      No                     No
# 71515                       No                      No                     No
# 71516                       No                      No                     No
# 71517                       No                      No                     No
#
#       change diabetesMed readmitted
# 0         No          No         No
# 1         Ch         Yes         No
# 2         No         Yes         No
# 3         Ch         Yes         No
# 4         Ch         Yes         No
# ...      ...         ...        ...
# 71513     Ch         Yes         No
# 71514     Ch         Yes         No
# 71515     No         Yes         No
# 71516     Ch         Yes         No
# 71517     No          No         No
#
# [71518 rows x 46 columns]
